# %%
# +ve bag and a -ve

# %%
#architecture of higher defined sequencing models
#RNN--LSTM--TRANSFORMERS

# %%
#Hidden state means the models current summary of what if has read so far

#the movie was not good

#token 1:The
#memory:sentence has started

#token 2:Movie
#memory:subject is movie

#token 3:was
#memory:waiting for description

#token 4:Not
#memory:negative active

#token 5:Good
#memory:good appears but not changing meaning

#Final sentiment:negation-negative

# %%
sentence = "the movie was not good"
tokens = sentence.split()

memory = ""

for token in tokens:
    memory = memory + " " + token
    print("Current token:", token)
    print("memory so far:", memory.strip())
# Out:
# Current token: the
# memory so far: the
# Current token: movie
# memory so far: the movie
# Current token: was
# memory so far: the movie was
# Current token: not
# memory so far: the movie was not
# Current token: good
# memory so far: the movie was not good

# %%
sentence = "the movie was not good"
tokens = sentence.split()

hidden_state = {
    "topic": None,
    "negation_active": False,
    "sentiment_word": None
}

for token in tokens:
    if token in ["movie", "food", "product"]:
        hidden_state["topic"] = token
        
    if token == "not":
        hidden_state["negation_active"] = True
        
    if token in ["good", "bad", "great", "terrible"]:
        hidden_state["sentiment_word"] = token
        
    print("Token:", token)
    print("Hidden state:", hidden_state)
    print("-----")
# Out:
# Token: the
# Hidden state: {'topic': None, 'negation_active': False, 'sentiment_word': None}
# -----
# Token: movie
# Hidden state: {'topic': 'movie', 'negation_active': False, 'sentiment_word': None}
# -----
# Token: was
# Hidden state: {'topic': 'movie', 'negation_active': False, 'sentiment_word': None}
# -----
# Token: not
# Hidden state: {'topic': 'movie', 'negation_active': True, 'sentiment_word': None}
# -----
# Token: good
# Hidden state: {'topic': 'movie', 'negation_active': True, 'sentiment_word': 'good'}
# -----

# %%
import tensorflow as tf
from tensorflow.keras import layers

vocab_size = 1000
embedding_dim = 16
sequence_length = 8

simple_rnn_model = tf.keras.Sequential([
    layers.Input(shape=(sequence_length,)),
    layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim),
    layers.SimpleRNN(32),
    layers.Dense(1, activation='sigmoid')
])

simple_rnn_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 8, 16)          │        16,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 32)             │         1,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,601 (68.75 KB)
#  Trainable params: 17,601 (68.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#RNNs cannot work with long term memory
#long dependency is a mstr

# as sequence length increases simple rnn memory becomes weak

#LSTM is an upgraded RNN

#LSTM=RNN+gates+cell states

#Cell state:long term memory path
#hidden state:current working memory

#forget gate:decides which old info to keep and which to drop

#Input gate
#point to input gate

#output gate


#forget gate-cross out old info which is no longer required
#input gate decide what new information deserves a note
#candidate memorry:the new note(important that could be written)
#cell state is the notebook

# %%
#sentence
#the movie was not good

#token:the 
#cell state:sentence started

#token:movie
#cell state:subject is movie

#token:was
#cell state:waiting for description

#token:not
#input gate adds negation
#cell state:negation is active


#token:good
#output gate exposes:not+good

#prediction becomes negative
